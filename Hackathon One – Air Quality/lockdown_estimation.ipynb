# %%
import pandas as pd
import matplotlib.pyplot as plt
import dtale

# %%
df = pd.read_csv("data/city_mapper/Citymapper_Mobility_Index_20200601.csv", skiprows = 3)

# %%
df = df.set_index('Date')

# %%
london = df["London"]

# %%
rolling_avg = london.rolling(7).mean()

# %%
plt.plot(london.index,london - rolling_avg)
# Out:
# 2020-06-01 22:28:31,488 - INFO     - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2020-06-01 22:28:31,499 - INFO     - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
